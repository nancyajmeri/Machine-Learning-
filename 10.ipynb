# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart_statlog_cleveland_hungary_final.csv')

# %%
data["target"].value_counts()
# Out:
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
x_norm = data.drop(['target'],axis = 1)
y  = data['target']
x_norm
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# 2                       0            1              98                0
# 3                       0            0             108                1
# 4                       0            0             122                0
# ...                   ...          ...             ...              ...
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope
# 0         0.0         1
# 1         1.0         2
# 2         0.0         1
# 3         1.5         2
# 4         0.0         1
# ...       ...       ...
# 1185      1.2         2
# 1186      3.4         2
# 1187      1.2         2
# 1188      0.0         2
# 1189      0.0         1
#
# [1190 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x_norm)
x
# Out:
# array([[-1.46672783,  0.55599543, -1.31835093, ..., -0.79521891,
#         -0.84979236, -1.02321701],
#        [-0.50460037, -1.79857595, -0.24893198, ..., -0.79521891,
#          0.07111913,  0.61558278],
#        [-1.78743698,  0.55599543, -1.31835093, ..., -0.79521891,
#         -0.84979236, -1.02321701],
#        ...,
#        [ 0.35062404,  0.55599543,  0.82048698, ...,  1.25751537,
#          0.25530143,  0.61558278],
#        [ 0.35062404, -1.79857595, -1.31835093, ..., -0.79521891,
#         -0.84979236,  0.61558278],
#        [-1.68053393,  0.55599543, -0.24893198, ..., -0.79521891,
#         -0.84979236, -1.02321701]], shape=(1190, 11))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
nb = GaussianNB()
nb
# Out:
# GaussianNB()

# %%
# Fit the model before prediction
y_pred_nb = nb.fit(x_train, y_train).predict(x_test)
acc_gnb = accuracy_score(y_test, y_pred_nb) * 100
print("Accuracy of Gaussian Naive Bayes: ", acc_gnb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Fit the model before prediction
#       2 y_pred_nb = nb.fit(x_train, y_train).predict(x_test)
# ----> 3 acc_gnb = accuracy_score(y_test, y_pred_nb) * 100
#       4 print("Accuracy of Gaussian Naive Bayes: ", acc_gnb)
#
# NameError: name 'accuracy_score' is not defined

# %%
nb_cm = confusion_matrix(y_test, y_pred_nb)
sns.heatmap(nb_cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85       107
#            1       0.87      0.88      0.87       131
#
#     accuracy                           0.86       238
#    macro avg       0.86      0.86      0.86       238
# weighted avg       0.86      0.86      0.86       238

# %%
acc_lr = accuracy_score(y_test, y_pred_lr) * 100
print("Accuracy of Logistic Regression: ", acc_lr)
lr_cm = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(lr_cm, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy of Logistic Regression:  86.1344537815126

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       107
#            1       0.93      0.86      0.89       131
#
#     accuracy                           0.89       238
#    macro avg       0.89      0.89      0.89       238
# weighted avg       0.89      0.89      0.89       238

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
y_pred_knn = knn.predict(x_test)

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       107
#            1       0.89      0.89      0.89       131
#
#     accuracy                           0.88       238
#    macro avg       0.88      0.88      0.88       238
# weighted avg       0.88      0.88      0.88       238

# %%
acc_knn = accuracy_score(y_test, y_pred_knn) * 100
print("Accuracy=", acc_knn)
knn_cm = confusion_matrix(y_test, y_pred_knn)
sns.heatmap(knn_cm, annot=True, fmt='d', cmap='Reds')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy= 87.81512605042016

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear',random_state=42)
svm.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred_svn = svm.predict(x_test)

# %%
print(classification_report(y_test, y_pred_svn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       107
#            1       0.86      0.86      0.86       131
#
#     accuracy                           0.84       238
#    macro avg       0.84      0.84      0.84       238
# weighted avg       0.84      0.84      0.84       238

# %%
acc_svm = accuracy_score(y_test, y_pred_svn) * 100
print("Accuracy of SVM: ", acc_svm)
# Out:
# Accuracy of SVM:  84.45378151260505

# %%
svm_cm = confusion_matrix(y_test, y_pred_svn)
sns.heatmap(svm_cm, annot=True, fmt='d', cmap='Purples')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
model_accuracies = {
    'Naive Bayes': acc_gnb,
    'Logistic Regression': acc_lr,
    'Decision Tree': acc_dt,
    'KNN': acc_knn,
    'SVM': acc_svm
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 model_accuracies = {
# ----> 2     'Naive Bayes': acc_gnb,
#       3     'Logistic Regression': acc_lr,
#       4     'Decision Tree': acc_dt,
#       5     'KNN': acc_knn,
#       6     'SVM': acc_svm
#       7 }
#
# NameError: name 'acc_gnb' is not defined
